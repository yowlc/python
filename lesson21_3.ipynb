# %%
import pandas as pd
import numpy as np

s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])
display(s1)
display(s2)
display(s3)
# Out:
# a    0
# b    1
# dtype: int64
# c    2
# d    3
# e    4
# dtype: int64
# f    5
# g    6
# dtype: int64

# %%
# Series 合併

display( pd.concat([s1, s2, s3]) )
display( pd.concat([s1, s2, s3], axis=1) )
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
df1 = pd.DataFrame(np.arange(6).reshape(3, 2),
                   index=['a', 'b', 'c'],
                   columns=['one','two'])
display(df1)
df2 = pd.DataFrame(np.arange(4).reshape(2, 2),
                   index=['a', 'c'],
                   columns=['three','four'])
display(df2)
# Out:
#    one  two
# a    0    1
# b    2    3
# c    4    5
#    three  four
# a      0     1
# c      2     3

# %%
# DataFrame 合併

pd.concat([df1, df2], axis=1)
# Out:
#    one  two  three  four
# a    0    1    0.0   1.0
# b    2    3    NaN   NaN
# c    4    5    2.0   3.0

# %%
pd.concat([df1, df2], axis=1, keys=['台北', '台南'])
# Out:
#    台北        台南
#   one two three four
# a   0   1   0.0  1.0
# b   2   3   NaN  NaN
# c   4   5   2.0  3.0

# %%
df1 = pd.DataFrame(np.random.randn(3, 4), columns=['a', 'b', 'c', 'd'])
display(df1)
df2 = pd.DataFrame(np.random.randn(2, 3), columns=['b', 'd', 'a'])
display(df2)
pd.concat([df1, df2])
# Out:
#           a         b         c         d
# 0  0.013862 -1.355618  0.535067 -0.980731
# 1 -0.485104 -0.692065  1.646037  1.058910
# 2  0.996855 -0.019336 -1.013898 -0.891176
#           b         d         a
# 0 -1.598950 -0.064137  0.983688
# 1  0.563572 -0.252619 -0.263159
#           a         b         c         d
# 0  0.013862 -1.355618  0.535067 -0.980731
# 1 -0.485104 -0.692065  1.646037  1.058910
# 2  0.996855 -0.019336 -1.013898 -0.891176
# 0  0.983688 -1.598950       NaN -0.064137
# 1 -0.263159  0.563572       NaN -0.252619

# %%
# ignore_index=True -> 重新索引

pd.concat([df1, df2], ignore_index=True)
# Out:
#           a         b         c         d
# 0  0.013862 -1.355618  0.535067 -0.980731
# 1 -0.485104 -0.692065  1.646037  1.058910
# 2  0.996855 -0.019336 -1.013898 -0.891176
# 3  0.983688 -1.598950       NaN -0.064137
# 4 -0.263159  0.563572       NaN -0.252619

# %%
import yfinance as yf

data1 = yf.download("2330.TW", start="2023-09-15", end="2023-10-03")
tw2330 = data1[ ['Adj Close'] ]

tw2330.columns = ['台積電']
display(tw2330)

data2 = yf.download("2303.TW", start="2023-09-15", end="2023-10-03")
tw2303 = data2[ ['Adj Close'] ]

tw2303.columns = ['聯電']
display(tw2303)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               台積電
# Date
# 2023-09-15  558.0
# 2023-09-18  540.0
# 2023-09-19  538.0
# 2023-09-20  535.0
# 2023-09-21  527.0
# 2023-09-22  522.0
# 2023-09-25  525.0
# 2023-09-26  519.0
# 2023-09-27  522.0
# 2023-09-28  523.0
# 2023-10-02  533.0
# [*********************100%%**********************]  1 of 1 completed
#                    聯電
# Date
# 2023-09-15  47.599998
# 2023-09-18  46.500000
# 2023-09-19  46.200001
# 2023-09-20  45.900002
# 2023-09-21  45.650002
# 2023-09-22  45.349998
# 2023-09-25  45.650002
# 2023-09-26  44.750000
# 2023-09-27  44.400002
# 2023-09-28  45.200001
# 2023-10-02  45.750000

# %%
pd.concat([tw2330, tw2303], axis=1)
# Out:
#               台積電         聯電
# Date
# 2023-09-15  558.0  47.599998
# 2023-09-18  540.0  46.500000
# 2023-09-19  538.0  46.200001
# 2023-09-20  535.0  45.900002
# 2023-09-21  527.0  45.650002
# 2023-09-22  522.0  45.349998
# 2023-09-25  525.0  45.650002
# 2023-09-26  519.0  44.750000
# 2023-09-27  522.0  44.400002
# 2023-09-28  523.0  45.200001
# 2023-10-02  533.0  45.750000
