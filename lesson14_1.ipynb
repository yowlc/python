# %%
import requests

url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
r = requests.get(url)
if r.status_code == 200:
    print('下載成功')
# Out:
# 下載成功

# %%
display(r.text)
display(r.json())
# Out:
# '{\n "cwbopendata": {\n  "@xmlns": "urn:cwb:gov:tw:cwbcommon:0.1",\n  "identifier": "938378d3-09be-5387-f506-b222768d98b0",\n  "sender": "weather@cwb.gov.tw",\n  "sent": "2023-09-07T16:45:02+08:00",\n  "status": "Actual",\n  "msgType": "Issue",\n  "source": "MFC",\n  "dataid": "C0032-001",\n  "scope": "Public",\n  "dataset": {\n   "datasetInfo": {\n    "datasetDescription": "三十六小時天氣預報",\n    "issueTime": "2023-09-07T17:00:00+08:00",\n    "update": "2023-09-07T16:45:02+08:00"\n   },\n   "location": [\n    {\n     "locationName": "臺北市",\n     "weatherElement": [\n      {\n       "elementName": "Wx",\n       "time": [\n        {\n         "startTime": "2023-09-07T18:00:00+08:00",\n         "endTime": "2023-09-08T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "陰時多雲短暫陣雨或雷雨",\n          "parameterValue": "17"\n         }\n        },\n        {\n         "startTime": "2023-09-08T06:00:00+08:00",\n         "endTime": "2023-09-08T18:00:00+08:00",\n         "parameter": 
# ...

# %%
# json 轉 簡單表格資料
all_json = r.json()
print(all_json['cwbopendata']['sent'])

locations = all_json['cwbopendata']['dataset']['location']

weather_list = []
for item in locations:
    city_item = {}
    city_item['城市'] = item['locationName']
    city_item['啓始時間'] = item['weatherElement'][1]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime']
    city_item['最高溫度'] = float(item['weatherElement'][1]['time'][0]['parameter']['parameterName'])
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)

print(weather_list)
# Out:
# 2023-09-07T16:45:02+08:00
# ...

# %%
import csv

filename = '目前各縣市天氣預測.csv'

with open(filename, mode='w', encoding='utf-8', newline='') as file:
    csv_writer = csv.DictWriter(file, fieldnames=['城市', '啓始時間', '結束時間', '最高溫度', '最低溫度', '感覺'])
    csv_writer.writeheader()
    csv_writer.writerows(weather_list)

print('存檔成功')
# Out:
# 存檔成功
